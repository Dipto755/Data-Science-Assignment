# %%
import pandas_datareader.data as web
import datetime
import pandas as pd

start = datetime.datetime(2016,1,1)
end = datetime.datetime(2017,1,1)

df = web.DataReader('BMW.DE', 'yahoo', start, end)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       5 start = datetime.datetime(2016,1,1)
#       6 end = datetime.datetime(2017,1,1)
# ----> 8 df = web.DataReader('BMW.DE', 'yahoo', start, end)
#       9 df.head()
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:210, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     208         raise TypeError(msg)
#     209     kwargs[new_arg_name] = new_arg_value
# --> 210 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas_datareader/data.py:379, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
#     370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
# ...

# %%
df = pd.read_csv('AAPL2.csv')

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close
# 0  2016-01-04  25.652500  26.342501  25.500000  26.337500  24.185043  \
# 1  2016-01-05  26.437500  26.462500  25.602501  25.677500  23.578985
# 2  2016-01-06  25.139999  25.592501  24.967501  25.174999  23.117554
# 3  2016-01-07  24.670000  25.032499  24.107500  24.112499  22.141886
# 4  2016-01-08  24.637501  24.777500  24.190001  24.240000  22.258966
#
#       Volume
# 0  270597600
# 1  223164000
# 2  273829600
# 3  324377600
# 4  283192000

# %%
# %matplotlib inline
df.plot(y="Close", color="Green")
# Out:
# <Axes: >

# %%
df.plot.bar(y="Volume")
# Out:
# <Axes: >

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/watch?v=4e_o4Xar5t0" frameborder="0" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/watch?v=4e_o4Xar5t0" frameborder="0" allowfullscreen></iframe>
